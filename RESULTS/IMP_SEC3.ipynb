# %% [markdown]
# # IMP example

# %% [markdown]
# #### Primer carreguem els mòduls de IMP.

# %%
import os
import sys
import shutil
import random
import csv

import IMP.core
import IMP.pmi.dof
import IMP.pmi.macros
import IMP.pmi.restraints.basic
import IMP.pmi.restraints.stereochemistry
import IMP.pmi.tools
import IMP.pmi.topology
import IMP.pmi.output

# %%
print(sys.version)
# Out:
# 3.8.10 (default, Mar 15 2022, 12:22:08)
# [GCC 9.4.0]

# %%
print(IMP.__version__)
# Out:
# 2.16.0

# %% [markdown]
# ## Functions

# %%
def create_tag_molecules(pict_bdb, pict_components, pict_chains, state_tags):
    """
    Create IMP.pmi molecules using fluorophore coordinates
    :param pict_bdb:
    :param pict_components:
    :param pict_chains:
    :param state_tags:
    :return:
    """
    colors = ["blue", "orange", "yellow", "pink", "brown", "purple", "red", "green"]
    tag_molecules = list()
    for n in range(len(pict_components)):
        print('PMI: setting up tag', pict_components[n])
        molecule = state_tags.create_molecule(name=pict_components[n],
                                              sequence="",
                                              chain_id=pict_chains[n])

        atomic = molecule.add_structure(pdb_fn=pict_bdb,
                                        chain_id=pict_chains[n],
                                        res_range=[],  # add only specific set of residues
                                        soft_check=True,  # warns sequence mismatches between fasta and PDB sequence
                                        offset=0)  # to sync PDB residue numbering with FASTA numbering.

        molecule.add_representation(residues=atomic,  # adding all residues of PDB to representation
                                    bead_extra_breaks=[],  # Additional breakpoints for splitting beads.
                                    color=colors[n],
                                    bead_ca_centers=True,  # resolution=1 beads to be at CA centers
                                    resolutions=[1])

        tag_molecules.append(molecule)

    return tag_molecules


def get_pict_distance_restraints_dict(dr_tags_file):
    """
    Return dictionary of distances between tags and termini of cryo exocyst
    :param dr_tags_file:
    """
    # Defining PICT distances (from tags to termini of subunits)
    distances_to_tags_dict = dict()
    with open(dr_tags_file, "r") as dr:
        "dr_file --> tag,tag_residue,protein,protein_residue,raw_distance,Added distance,Final Distance"
        csv_reader = csv.reader(dr, delimiter=',')  # to parse the csv file delimited with commas.
        dr.readline()  # skip first line
        for line in csv_reader:
            tag = line[0]
            protein = line[2]
            tag_residue = int(line[1])
            protein_residue = int(line[3])
            chain_id = str(line[4])
            max_distance = float(line[7])
            raw_dist = float(line[5])
            sd = float(line[8])
            if raw_dist == 202:
                distances_to_tags_dict.setdefault("{}_frb-{}_C".format(tag, protein),
                                                  [tag, protein, tag_residue, protein_residue, chain_id, max_distance,
                                                   sd])

            elif raw_dist == 110:
                distances_to_tags_dict.setdefault("{}_gfp_c-{}_C".format(tag, protein),
                                                  [tag, protein, tag_residue, protein_residue, chain_id, max_distance,
                                                   sd])

            else:
                distances_to_tags_dict.setdefault("{}_gfp_n-{}_N".format(tag, protein),
                                                  [tag, protein, tag_residue, protein_residue, chain_id, max_distance,
                                                   sd])
    return distances_to_tags_dict

def set_pict_distance_restraints(distances_to_tags_dict, root_hierarchy, output_objects):
    """
    Setting and adding basic Harmonic Upper Bound distance restraints from distances_to_tags
    dictionary
    :return: distances_to_tags_dict, dr_list, output_objects
    """
    # Distance restraints to positioned tags:
    dr_list = list()
    for r, data in distances_to_tags_dict.items():
        tag = data[0]
        protein = data[1]
        tag_rn = int(data[2])
        protein_rn = int(data[3])
        max_distance = float(data[5])
        sd = float(data[6])
        kappa = IMP.core.Harmonic_get_k_from_standard_deviation(sd)
        dr = IMP.pmi.restraints.basic.DistanceRestraint(root_hier=root_hierarchy,
                                                        tuple_selection1=(tag_rn, tag_rn, tag),
                                                        tuple_selection2=(protein_rn, protein_rn, protein),
                                                        distancemin=0,
                                                        distancemax=max_distance,
                                                        # kappa=kappa,
                                                        label="restraint_{}".format(r))
        dr.add_to_model()
        dr.evaluate()
        dr_list.append(dr)
        output_objects.append(dr)
        print("\nSetting distance {}\n".format(dr.label))
        print("Max distance {}\n".format(max_distance))

    return distances_to_tags_dict, dr_list, output_objects


def distance_restraints_pict_cryo(dr_tags_file, root_hierarchy, output_objects):
    # Defining PICT distances (from tags to termini of subunits)
    distances_to_tags_dict = get_pict_distance_restraints_dict(dr_tags_file)

    # Distance restraints to positioned tags:
    return set_pict_distance_restraints(distances_to_tags_dict, root_hierarchy, output_objects)

# %% [markdown]
# ## Define PATHS
#
# define the peaths for the data (input) and where to store the results (output)

# %%
# ---------------------------
# 1. Define Input Data and Output Directories
# ---------------------------
data_directory = "/your/path/to/TFM/RESULTS/SEC3/IMP/input/data/"                             # input dir
# topology_file = data_directory + "SEC3_custom.topology"           # aquí defineixo paràmetres del model
topology_file = data_directory + "topology_wrb.txt" 
cryo_pdb_model = data_directory + "5yfp.pdb"                  # PDB cryoEM
pict_pdb_models = data_directory + "fluorophores_modified/"   # Fluorophores information
dr_tags_file = data_directory + "distance_restraints.csv"     # Restraints de distància en un CSV
output_directory = "./output/cryoEM/output/iterations/wr"    # Output dir
# output_index = sys.argv[1]  # N (number iterations )output prefix
output_index = 4

# %% [markdown]
# ## Parameters
#
# Define parameters for Monte Carlo Replica Exchange and for excluded volume and connectivity restraints.

# %%
# --------------------------
# 2. Scoring Parameters
# --------------------------

# --------------
# ----- Sterochemistry and Physical Restraints
ev_weight = 1.0  # Weight of excluded volume restraint
connectivity_scale = 1.2  # weight of Connectivity restraint

# --------------------
# 3. Sampling Parameters
# --------------------
num_frames = 100  # int(sys.argv[3])   # Number of frames in MC run
num_best_scoring_models = 3
num_mc_steps = 50  # Number of MC steps per frame
mc_temperature = 1.0  # Temperature for MC

# --- Simulated Annealing (sa)
#  - Alternates between two MC temperatures
sim_annealing = True  # If true, run simulated annealing
sa_min_temp_steps = 100  # Steps at min temp
sa_max_temp_steps = 20  # Steps at max temp
sa_temps = (1.0, 5.0)  # Sim annealing temperatures

# Replica Exchange (rex)
rex_temps = (1.0, 5.0)  # Temperature bounds for replica exchange

# %% [markdown]
# ## MODELING

# %% [markdown]
# First, define the model and load the data from the [IMP Topology file](https://integrativemodeling.org/2.15.0/doc/ref/classIMP_1_1pmi_1_1topology_1_1TopologyReader.html).

# %%
# Initialize model
m = IMP.Model()
# Read in the topology file --> to coarse model of exocyst
# Specify the directory where the PDB files and fasta files
topology = IMP.pmi.topology.TopologyReader(topology_file,
                                           pdb_dir="/home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3",
                                           fasta_dir="/home/gallegolab/Desktop/TFM/test_TFM/TFM/input_fasta")
                                           # pdb_dir=data_directory,
                                           # fasta_dir=data_directory)
# Use the BuildSystem macro to build states from the topology file
bs = IMP.pmi.macros.BuildSystem(m)

# %% [markdown]
# Define the fluorophores data, number of particles and their coordinates from the PDB files. we create a state inside the BuildSystem object defined as "bs"

# %%
# Define tag molecules (fluorophores) as chains and component names and load state
pict_pdb = random.choice(os.listdir(pict_pdb_models))  # get a tag model file randomly
pict_pdb_seqs = IMP.pmi.topology.PDBSequences(m, pict_pdb_models + pict_pdb)  # using IMP.model
pict_chains = [chain for chain in pict_pdb_seqs.sequences]
pict_components = ["tag_sec3", "tag_sec5", "tag_sec6", "tag_sec8", "tag_sec10", "tag_sec15", "tag_exo70", "tag_exo84"]
st_tags = bs.system.create_state()
# Each state can be specified by a topology file.
# Create tag molecules and load to system
tag_molecules = create_tag_molecules(pict_pdb_models + pict_pdb, pict_components, pict_chains, st_tags)
# Out:
# A
# B
# C
# D
# E
# F
# G
# H
# PMI: setting up tag tag_sec3
# PMI: setting up tag tag_sec5
# PMI: setting up tag tag_sec6
# PMI: setting up tag tag_sec8
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:560: StructureWarning: Substituting PDB residue type with FASTA residue type. Potentially dangerous.
#   warnings.warn(
# PMI: setting up tag tag_sec10
# PMI: setting up tag tag_sec15
# PMI: setting up tag tag_exo70
# PMI: setting up tag tag_exo84

# %% [markdown]
# Load the structure from the Exocyst from the Topology File

# %%
bs.add_state(topology)
system_molecules = bs.get_molecules()
cryo_components = [mol[1][0] for mol in system_molecules[1].items()]
# Out:
# BuildSystem.add_state: setting up molecule sec5 copy number 0
# BuildSystem.add_state: molecule sec5 sequence has 971 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule sec5
# BuildSystem.add_state: -------- domain 0 of molecule sec5 extends from residue 1 to residue 154
# BuildSystem.add_state: -------- domain 0 of molecule sec5 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule sec5
# BuildSystem.add_state: -------- domain 1 of molecule sec5 extends from residue 155 to residue 231
# BuildSystem.add_state: -------- domain 1 of molecule sec5 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule sec5
# BuildSystem.add_state: -------- domain 2 of molecule sec5 extends from residue 232 to residue 971
# BuildSystem.add_state: -------- domain 2 of molecule sec5 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule sec6 copy number 0
# BuildSystem.add_state: molecule sec6 sequence has 805 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule sec6
# BuildSystem.add_state: -------- domain 0 of molecule sec6 extends from residue 1 to residue 17
# BuildSystem.add_state: -------- domain 0 of molecule sec6 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule sec6
# BuildSystem.add_state: -------- domain 1 of molecule sec6 extends from residue 18 to residue 88
# BuildSystem.add_state: -------- domain 1 of molecule sec6 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule sec6
# BuildSystem.add_state: -------- domain 2 of molecule sec6 extends from residue 89 to residue 805
# BuildSystem.add_state: -------- domain 2 of molecule sec6 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule sec8 copy number 0
# BuildSystem.add_state: molecule sec8 sequence has 1065 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule sec8
# BuildSystem.add_state: -------- domain 0 of molecule sec8 extends from residue 22 to residue 90
# BuildSystem.add_state: -------- domain 0 of molecule sec8 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule sec8
# BuildSystem.add_state: -------- domain 1 of molecule sec8 extends from residue 91 to residue 177
# BuildSystem.add_state: -------- domain 1 of molecule sec8 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule sec8
# BuildSystem.add_state: -------- domain 2 of molecule sec8 extends from residue 178 to residue 1065
# BuildSystem.add_state: -------- domain 2 of molecule sec8 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule sec10 copy number 0
# BuildSystem.add_state: molecule sec10 sequence has 871 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule sec10
# BuildSystem.add_state: -------- domain 0 of molecule sec10 extends from residue 3 to residue 57
# BuildSystem.add_state: -------- domain 0 of molecule sec10 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule sec10
# BuildSystem.add_state: -------- domain 1 of molecule sec10 extends from residue 58 to residue 172
# BuildSystem.add_state: -------- domain 1 of molecule sec10 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule sec10
# BuildSystem.add_state: -------- domain 2 of molecule sec10 extends from residue 173 to residue 867
# BuildSystem.add_state: -------- domain 2 of molecule sec10 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule sec15 copy number 0
# BuildSystem.add_state: molecule sec15 sequence has 910 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule sec15
# BuildSystem.add_state: -------- domain 0 of molecule sec15 extends from residue 42 to residue 77
# BuildSystem.add_state: -------- domain 0 of molecule sec15 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule sec15
# BuildSystem.add_state: -------- domain 1 of molecule sec15 extends from residue 78 to residue 186
# BuildSystem.add_state: -------- domain 1 of molecule sec15 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule sec15
# BuildSystem.add_state: -------- domain 2 of molecule sec15 extends from residue 189 to residue 890
# BuildSystem.add_state: -------- domain 2 of molecule sec15 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule exo70 copy number 0
# BuildSystem.add_state: molecule exo70 sequence has 623 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule exo70
# BuildSystem.add_state: -------- domain 0 of molecule exo70 extends from residue 1 to residue 68
# BuildSystem.add_state: -------- domain 0 of molecule exo70 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule exo70
# BuildSystem.add_state: -------- domain 1 of molecule exo70 extends from residue 69 to residue 114
# BuildSystem.add_state: -------- domain 1 of molecule exo70 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule exo70
# BuildSystem.add_state: -------- domain 2 of molecule exo70 extends from residue 115 to residue 623
# BuildSystem.add_state: -------- domain 2 of molecule exo70 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule exo84 copy number 0
# BuildSystem.add_state: molecule exo84 sequence has 753 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule exo84
# BuildSystem.add_state: -------- domain 0 of molecule exo84 extends from residue 169 to residue 196
# BuildSystem.add_state: -------- domain 0 of molecule exo84 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 1 of molecule exo84
# BuildSystem.add_state: -------- domain 1 of molecule exo84 extends from residue 197 to residue 276
# BuildSystem.add_state: -------- domain 1 of molecule exo84 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: ---- setting up domain 2 of molecule exo84
# BuildSystem.add_state: -------- domain 2 of molecule exo84 extends from residue 277 to residue 753
# BuildSystem.add_state: -------- domain 2 of molecule exo84 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/IMP/input/data/5yfp.pdb
# BuildSystem.add_state: setting up molecule SEC3 copy number 0
# BuildSystem.add_state: molecule SEC3 sequence has 1336 residues
# BuildSystem.add_state: ---- setting up domain 0 of molecule SEC3
# BuildSystem.add_state: -------- domain 0 of molecule SEC3 extends from residue 1 to residue 73
# BuildSystem.add_state: -------- domain 0 of molecule SEC3 represented by BEADS
# BuildSystem.add_state: ---- setting up domain 1 of molecule SEC3
# BuildSystem.add_state: -------- domain 1 of molecule SEC3 extends from residue 74 to residue 249
# BuildSystem.add_state: -------- domain 1 of molecule SEC3 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/PDB/5lg4.cif
# BuildSystem.add_state: ---- setting up domain 2 of molecule SEC3
# BuildSystem.add_state: -------- domain 2 of molecule SEC3 extends from residue 250 to residue 324
# BuildSystem.add_state: -------- domain 2 of molecule SEC3 represented by BEADS
# BuildSystem.add_state: ---- setting up domain 3 of molecule SEC3
# BuildSystem.add_state: -------- domain 3 of molecule SEC3 extends from residue 325 to residue 450
# BuildSystem.add_state: -------- domain 3 of molecule SEC3 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/ALPHAFOLD/DOMAINS/SEC3_AF_domains.pdb
# BuildSystem.add_state: ---- setting up domain 4 of molecule SEC3
# BuildSystem.add_state: -------- domain 4 of molecule SEC3 extends from residue 451 to residue 610
# BuildSystem.add_state: -------- domain 4 of molecule SEC3 represented by BEADS
# BuildSystem.add_state: ---- setting up domain 5 of molecule SEC3
# BuildSystem.add_state: -------- domain 5 of molecule SEC3 extends from residue 611 to residue 1332
# BuildSystem.add_state: -------- domain 5 of molecule SEC3 represented by pdb file /home/gallegolab/Desktop/TFM/test_TFM/TFM/RESULTS/SEC3/PDB/5yfp.cif
# BuildSystem.add_state: ---- setting up domain 6 of molecule SEC3
# BuildSystem.add_state: -------- domain 6 of molecule SEC3 extends from residue 1333 to residue 1336
# BuildSystem.add_state: -------- domain 6 of molecule SEC3 represented by BEADS
# BuildSystem.add_state: State 2 added
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:1249: StructureWarning: Inconsistency between FASTA sequence and PDB sequence. FASTA type 74 "THR" and PDB type "MET"
#   warnings.warn(

# %% [markdown]
# Finally, we create our system using a macro from IMP.

# %%
# Build the system representation and degrees of freedom
root_hierarchy, dof = bs.execute_macro(max_rb_trans=4.0,
                                       max_rb_rot=0.3,
                                       max_bead_trans=4.0,
                                       max_srb_trans=4.0,
                                       max_srb_rot=0.3)
# Out:
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_sec3: 1-3000
#   warnings.warn(
# BuildSystem.execute_macro: building representations
# done building "tag_sec3" Chain A Copy: 0
# done building "tag_sec5" Chain B Copy: 0
# done building "tag_sec6" Chain C Copy: 0
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_sec5: 1-3003
#   warnings.warn(
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_sec6: 1-3005
#   warnings.warn(
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_sec8: 1-3008
#   warnings.warn(
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_sec10: 1-3010
#   warnings.warn(
# done building "tag_sec8" Chain D Copy: 0
# done building "tag_sec10" Chain E Copy: 0
# done building "tag_sec15" Chain F Copy: 0
# done building "tag_exo70" Chain G Copy: 0
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_sec15: 1-3013
#   warnings.warn(
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_exo70: 1-3016
#   warnings.warn(
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule tag_exo84: 1-3019
#   warnings.warn(
# done building "tag_exo84" Chain H Copy: 0
# done building "sec5" Chain A Copy: 0
# done building "sec6" Chain B Copy: 0
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule sec8: 1-21
#   warnings.warn(
# done building "sec8" Chain C Copy: 0
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule sec10: 1-2, 868-871
#   warnings.warn(
# done building "sec10" Chain D Copy: 0
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule sec15: 1-41, 187-188, 891-910
#   warnings.warn(
# done building "sec15" Chain E Copy: 0
# done building "exo70" Chain F Copy: 0
# /usr/lib/python3.8/dist-packages/IMP/pmi/topology/__init__.py:816: StructureWarning: Residues without representation in molecule exo84: 1-168
#   warnings.warn(
# done building "exo84" Chain G Copy: 0
# done building "SEC3" Chain H Copy: 0
# BuildSystem.execute_macro: setting up degrees of freedom
# BuildSystem.execute_macro: -------- building rigid body ['sec5..0', 'sec5..1', 'sec5..2', 'SEC3..0', 'SEC3..1']
# BuildSystem.execute_macro: -------- adding sec5..0
# BuildSystem.execute_macro: -------- adding sec5..1
# BuildSystem.execute_macro: -------- adding sec5..2
# BuildSystem.execute_macro: -------- adding SEC3..0
# BuildSystem.execute_macro: -------- adding SEC3..1
# BuildSystem.execute_macro: -------- creating rigid body with max_trans 4.0 max_rot 0.3 non_rigid_max_trans 4.0
# BuildSystem.execute_macro: -------- building rigid body ['sec6..0', 'sec6..1', 'sec6..2', 'SEC3..2', 'SEC3..3']
# BuildSystem.execute_macro: -------- adding sec6..0
# BuildSystem.execute_macro: -------- adding sec6..1
# BuildSystem.execute_macro: -------- adding sec6..2
# BuildSystem.execute_macro: -------- adding SEC3..2
# BuildSystem.execute_macro: -------- adding SEC3..3
# BuildSystem.execute_macro: -------- creating rigid body with max_trans 4.0 max_rot 0.3 non_rigid_max_trans 4.0
# BuildSystem.execute_macro: -------- building rigid body ['sec8..0', 'sec8..1', 'sec8..2', 'SEC3..4', 'SEC3..5']
# BuildSystem.execute_macro: -------- adding sec8..0
# BuildSystem.execute_macro: -------- adding sec8..1
# BuildSystem.execute_macro: -------- adding sec8..2
# BuildSystem.execute_macro: -------- adding SEC3..4
# BuildSystem.execute_macro: -------- adding SEC3..5
# BuildSystem.execute_macro: -------- creating rigid body with max_trans 4.0 max_rot 0.3 non_rigid_max_trans 4.0
# BuildSystem.execute_macro: -------- building rigid body ['sec10..0', 'sec10..1', 'sec10..2', 'sec15..0', 'sec15..1', 'sec15..2', 'exo70..0', 'exo70..1', 'exo70..2', 'exo84..0', 'exo84..1', 'exo84..2', 'SEC3..6']
# BuildSystem.execute_macro: -------- adding sec10..0
# BuildSystem.execute_macro: -------- adding sec10..1
# BuildSystem.execute_macro: -------- adding sec10..2
# BuildSystem.execute_macro: -------- adding sec15..0
# BuildSystem.execute_macro: -------- adding sec15..1
# BuildSystem.execute_macro: -------- adding sec15..2
# BuildSystem.execute_macro: -------- adding exo70..0
# BuildSystem.execute_macro: -------- adding exo70..1
# BuildSystem.execute_macro: -------- adding exo70..2
# BuildSystem.execute_macro: -------- adding exo84..0
# BuildSystem.execute_macro: -------- adding exo84..1
# BuildSystem.execute_macro: -------- adding exo84..2
# BuildSystem.execute_macro: -------- adding SEC3..6
# BuildSystem.execute_macro: -------- creating rigid body with max_trans 4.0 max_rot 0.3 non_rigid_max_trans 4.0
# BuildSystem.execute_macro: -------- building super rigid body ['sec5..0', 'sec5..1', 'sec5..2', 'sec6..0', 'sec6..1', 'sec6..2', 'sec8..0', 'sec8..1', 'sec8..2']
# BuildSystem.execute_macro: -------- adding sec5..0
# BuildSystem.execute_macro: -------- adding sec5..1
# BuildSystem.execute_macro: -------- adding sec5..2
# BuildSystem.execute_macro: -------- adding sec6..0
# BuildSystem.execute_macro: -------- adding sec6..1
# BuildSystem.execute_macro: -------- adding sec6..2
# BuildSystem.execute_macro: -------- adding sec8..0
# BuildSystem.execute_macro: -------- adding sec8..1
# BuildSystem.execute_macro: -------- adding sec8..2
# BuildSystem.execute_macro: -------- creating super rigid body with max_trans 4.0 max_rot 0.3
# BuildSystem.execute_macro: -------- building super rigid body ['sec10..0', 'sec10..1', 'sec10..2', 'sec15..0', 'sec15..1', 'sec15..2', 'exo70..0', 'exo70..1', 'exo70..2', 'exo84..0', 'exo84..1', 'exo84..2']
# BuildSystem.execute_macro: -------- adding sec10..0
# BuildSystem.execute_macro: -------- adding sec10..1
# BuildSystem.execute_macro: -------- adding sec10..2
# BuildSystem.execute_macro: -------- adding sec15..0
# BuildSystem.execute_macro: -------- adding sec15..1
# BuildSystem.execute_macro: -------- adding sec15..2
# BuildSystem.execute_macro: -------- adding exo70..0
# BuildSystem.execute_macro: -------- adding exo70..1
# BuildSystem.execute_macro: -------- adding exo70..2
# BuildSystem.execute_macro: -------- adding exo84..0
# BuildSystem.execute_macro: -------- adding exo84..1
# BuildSystem.execute_macro: -------- adding exo84..2
# BuildSystem.execute_macro: -------- creating super rigid body with max_trans 4.0 max_rot 0.3

# %% [markdown]
# We want only the exocyst to move, not the fluorophores, so we "disable movers" for the fluorophores.
#
# Afther that, we set up a random initialization (shuffle_configuration)

# %%
# Fix tags rigid bodies but not the exocyst (the protein complex)
fixed_beads, fixed_rbs = dof.disable_movers(tag_molecules,
                                            [IMP.core.RigidBodyMover,
                                             IMP.pmi.TransformMover])

# Randomize the initial configuration before sampling, of only the molecules
# we are interested in (exocyst subunits)
IMP.pmi.tools.shuffle_configuration(root_hierarchy,
                                    excluded_rigid_bodies=dof.get_rigid_bodies(),
                                    max_translation=50,
                                    verbose=False,
                                    cutoff=5.0,
                                    niterations=100)
# Out:
# Fixing 0 movers
# shuffling 4 rigid bodies
# shuffling 126 flexible beads

# %% [markdown]
# ### Define Scoring Functions Components

# %% [markdown]
# Now, we define the restraints
#
# - Distance restraints: --> in distance-restraints.csv . We implement them with IMP Harmonic Upper Bound restraints.
#
# - Connectivity --> to make sure each molecule is fully connected within itself.
#
# - Excluded Volume --> to avoid clashes.

# %%
out_objects = list()  # reporter objects (for stat files)

# %% [markdown]
# ### Distance Restraints

# %%
# Here we are defining a number of restraints on our system.
#  For all of them we call add_to_model() so they are incorporated into scoring
#  We also add them to the output_objects list, so they are reported in stat files

# Distances restraints from fluorophores to cryo subunits
dr_tags_dict, dr_list, output_objects = distance_restraints_pict_cryo(dr_tags_file, root_hierarchy, out_objects)
# Out:
# DistanceRestraint
# Created distance restraint between Residue_3001 and Residue_1332
#
# Setting distance restraint_tag_sec3_frb-SEC3_C
#
# Max distance 215.95
#
# DistanceRestraint
# Created distance restraint between Residue_3002 and Residue_1332
#
# Setting distance restraint_tag_sec3_gfp_c-SEC3_C
#
# Max distance 124.0
#
# DistanceRestraint
# Created distance restraint between Residue_3003 and Residue_611
#
# Setting distance restraint_tag_sec3_gfp_n-SEC3_N
#
# Max distance 341.5
#
# DistanceRestraint
# Created distance restraint between Residue_3004 and Residue_971
#
# Setting distance restraint_tag_sec5_gfp_c-sec5_C
#
# Max distance 110.0
#
# DistanceRestraint
# Created distance restraint between Residue_3005 and Residue_1
#
# Setting distance restraint_tag_sec5_gfp_n-sec5_N
#
# Max distance 112.0
#
# DistanceRestraint
# Created distance restraint between Residue_3006 and Residue_805
#
# Setting distance restraint_tag_sec6_frb-sec6_C
#
# Max distance 201.95
#
# DistanceRestraint
# Created distance restraint between Residue_3007 and Residue_805
#
# Setting distance restraint_tag_sec6_gfp_c-sec6_C
#
# Max distance 110.0
#
# DistanceRestraint
# Created distance restraint between Residue_3008 and Residue_1
#
# Setting distance restraint_tag_sec6_gfp_n-sec6_N
#
# Max distance 112.0
#
# DistanceRestraint
# Created distance restraint between Residue_3009 and Residue_1065
#
# Setting distance restraint_tag_sec8_frb-sec8_C
#
# Max distance 201.95
#
# DistanceRestraint
# Created distance restraint between Residue_3010 and Residue_1065
#
# Setting distance restraint_tag_sec8_gfp_c-sec8_C
#
# Max distance 110.0
#
# DistanceRestraint
# Created distance restraint between Residue_3011 and Residue_867
#
# Setting distance restraint_tag_sec10_frb-sec10_C
#
# Max distance 215.95
#
# DistanceRestraint
# Created distance restraint between Residue_3012 and Residue_867
#
# Setting distance restraint_tag_sec10_gfp_c-sec10_C
#
# Max distance 124.0
#
# DistanceRestraint
# Created distance restraint between Residue_3013 and Residue_3
#
# Setting distance restraint_tag_sec10_gfp_n-sec10_N
#
# Max distance 119.0
#
# DistanceRestraint
# Created distance restraint between Residue_3014 and Residue_890
#
# Setting distance restraint_tag_sec15_frb-sec15_C
#
# Max distance 271.95
#
# DistanceRestraint
# Created distance restraint between Residue_3015 and Residue_890
#
# Setting distance restraint_tag_sec15_gfp_c-sec15_C
#
# Max distance 180.0
#
# DistanceRestraint
# Created distance restraint between Residue_3016 and Residue_42
#
# Setting distance restraint_tag_sec15_gfp_n-sec15_N
#
# Max distance 137.0
#
# DistanceRestraint
# Created distance restraint between Residue_3017 and Residue_623
#
# Setting distance restraint_tag_exo70_frb-exo70_C
#
# Max distance 216.95
#
# DistanceRestraint
# Created distance restraint between Residue_3018 and Residue_623
#
# Setting distance restraint_tag_exo70_gfp_c-exo70_C
#
# Max distance 125.0
#
# DistanceRestraint
# Created distance restraint between Residue_3019 and Residue_1
#
# Setting distance restraint_tag_exo70_gfp_n-exo70_N
#
# Max distance 112.0
#
# DistanceRestraint
# Created distance restraint between Residue_3020 and Residue_753
#
# Setting distance restraint_tag_exo84_frb-exo84_C
#
# Max distance 201.95
#
# DistanceRestraint
# Created distance restraint between Residue_3021 and Residue_753
#
# Setting distance restraint_tag_exo84_gfp_c-exo84_C
#
# Max distance 110.0
#
# DistanceRestraint
# Created distance restraint between Residue_3022 and Residue_169
#
# Setting distance restraint_tag_exo84_gfp_n-exo84_N
#
# Max distance 163.0

# %% [markdown]
# ### Connectivity

# %%
# Connectivity keeps things connected along the backbone (ignores if inside
# same rigid body)
all_molecules = IMP.pmi.tools.get_molecules(root_hierarchy)
cryo_molecules = [mol for mol in all_molecules if "tag" not in mol.get_name()]
cr_list = list()
for mol in cryo_molecules:
    mol_name = mol.get_name()
    IMP.pmi.tools.display_bonds(mol)
    cr = IMP.pmi.restraints.stereochemistry.ConnectivityRestraint(mol, scale=connectivity_scale)
    cr.add_to_model()
    cr.set_label(mol_name)
    output_objects.append(cr)
    cr_list.append(cr)
# Out:
# Adding sequence connectivity restraint between 1-10_bead  and  11-20_bead of distance 4.32
# Adding sequence connectivity restraint between 11-20_bead  and  21-30_bead of distance 4.32
# Adding sequence connectivity restraint between 21-30_bead  and  31-40_bead of distance 4.32
# Adding sequence connectivity restraint between 31-40_bead  and  41-50_bead of distance 4.32
# Adding sequence connectivity restraint between 41-50_bead  and  51-60_bead of distance 4.32
# Adding sequence connectivity restraint between 51-60_bead  and  61-70_bead of distance 4.32
# Adding sequence connectivity restraint between 61-70_bead  and  71-73_bead of distance 4.32
# Adding sequence connectivity restraint between 71-73_bead  and  Residue_74 of distance 4.32
# Adding sequence connectivity restraint between Residue_99  and  100-101_bead of distance 4.32
# Adding sequence connectivity restraint between 100-101_bead  and  Residue_102 of distance 4.32
# Adding sequence connectivity restraint between Residue_249  and  250-253_bead of distance 4.32
# Adding sequence connectivity restraint between 250-253_bead  and  254-257_bead of distance 4.32
# Adding sequence connectivity restraint between 254-257_bead  and  258-261_bead of distance 4.32
# Adding sequence connectivity restraint between 258-261_bead  and  262-265_bead of distance 4.32
# Adding sequence connectivity restraint between 262-265_bead  and  266-269_bead of distance 4.32
# Adding sequence connectivity restraint between 266-269_bead  and  270-273_bead of distance 4.32
# Adding sequence connectivity restraint between 270-273_bead  and  274-277_bead of distance 4.32
# Adding sequence connectivity restraint between 274-277_bead  and  278-281_bead of distance 4.32
# Adding sequence connectivity restraint between 278-281_bead  and  282-285_bead of distance 4.32
# Adding sequence connectivity restraint between 282-285_bead  and  286-289_bead of distance 4.32
# Adding sequence connectivity restraint between 286-289_bead  and  290-293_bead of distance 4.32
# Adding sequence connectivity restraint between 290-293_bead  and  294-297_bead of distance 4.32
# Adding sequence connectivity restraint between 294-297_bead  and  298-301_bead of distance 4.32
# Adding sequence connectivity restraint between 298-301_bead  and  302-305_bead of distance 4.32
# Adding sequence connectivity restraint between 302-305_bead  and  306-309_bead of distance 4.32
# Adding sequence connectivity restraint between 306-309_bead  and  310-313_bead of distance 4.32
# Adding sequence connectivity restraint between 310-313_bead  and  314-317_bead of distance 4.32
# Adding sequence connectivity restraint between 314-317_bead  and  318-321_bead of distance 4.32
# Adding sequence connectivity restraint between 318-321_bead  and  322-324_bead of distance 4.32
# Adding sequence connectivity restraint between 322-324_bead  and  Residue_325 of distance 4.32
# Adding sequence connectivity restraint between Residue_450  and  451-460_bead of distance 4.32
# Adding sequence connectivity restraint between 451-460_bead  and  461-470_bead of distance 4.32
# Adding sequence connectivity restraint between 461-470_bead  and  471-480_bead of distance 4.32
# Adding sequence connectivity restraint between 471-480_bead  and  481-490_bead of distance 4.32
# Adding sequence connectivity restraint between 481-490_bead  and  491-500_bead of distance 4.32
# Adding sequence connectivity restraint between 491-500_bead  and  501-510_bead of distance 4.32
# Adding sequence connectivity restraint between 501-510_bead  and  511-520_bead of distance 4.32
# Adding sequence connectivity restraint between 511-520_bead  and  521-530_bead of distance 4.32
# Adding sequence connectivity restraint between 521-530_bead  and  531-540_bead of distance 4.32
# Adding sequence connectivity restraint between 531-540_bead  and  541-550_bead of distance 4.32
# Adding sequence connectivity restraint between 541-550_bead  and  551-560_bead of distance 4.32
# Adding sequence connectivity restraint between 551-560_bead  and  561-570_bead of distance 4.32
# Adding sequence connectivity restraint between 561-570_bead  and  571-580_bead of distance 4.32
# Adding sequence connectivity restraint between 571-580_bead  and  581-590_bead of distance 4.32
# Adding sequence connectivity restraint between 581-590_bead  and  591-600_bead of distance 4.32
# Adding sequence connectivity restraint between 591-600_bead  and  601-610_bead of distance 4.32
# Adding sequence connectivity restraint between 601-610_bead  and  Residue_611 of distance 4.32
# Adding sequence connectivity restraint between Residue_1135  and  1136-1145_bead of distance 4.32
# Adding sequence connectivity restraint between 1136-1145_bead  and  1146-1155_bead of distance 4.32
# Adding sequence connectivity restraint between 1146-1155_bead  and  Residue_1156 of distance 4.32
# Adding sequence connectivity restraint between Residue_1176  and  1177-1181_bead of distance 4.32
# Adding sequence connectivity restraint between 1177-1181_bead  and  Residue_1182 of distance 4.32
# Adding sequence connectivity restraint between Residue_1228  and  1229-1238_bead of distance 4.32
# Adding sequence connectivity restraint between 1229-1238_bead  and  1239-1244_bead of distance 4.32
# Adding sequence connectivity restraint between 1239-1244_bead  and  Residue_1245 of distance 4.32
# Adding sequence connectivity restraint between Residue_1313  and  1314-1322_bead of distance 4.32
# Adding sequence connectivity restraint between 1314-1322_bead  and  Residue_1323 of distance 4.32
# Adding sequence connectivity restraint between Residue_1332  and  1333-1336_bead of distance 4.32
# Adding sequence connectivity restraint between Residue_297  and  298-307_bead of distance 4.32
# Adding sequence connectivity restraint between 298-307_bead  and  308-317_bead of distance 4.32
# Adding sequence connectivity restraint between 308-317_bead  and  Residue_318 of distance 4.32
# Adding sequence connectivity restraint between Residue_474  and  475-484_bead of distance 4.32
# Adding sequence connectivity restraint between 475-484_bead  and  485-494_bead of distance 4.32
# Adding sequence connectivity restraint between 485-494_bead  and  495-497_bead of distance 4.32
# Adding sequence connectivity restraint between 495-497_bead  and  Residue_498 of distance 4.32
# Adding sequence connectivity restraint between Residue_526  and  527-536_bead of distance 4.32
# Adding sequence connectivity restraint between 527-536_bead  and  537-545_bead of distance 4.32
# Adding sequence connectivity restraint between 537-545_bead  and  Residue_546 of distance 4.32
# Adding sequence connectivity restraint between Residue_1009  and  1010-1019_bead of distance 4.32
# Adding sequence connectivity restraint between 1010-1019_bead  and  1020-1029_bead of distance 4.32
# Adding sequence connectivity restraint between 1020-1029_bead  and  1030-1037_bead of distance 4.32
# Adding sequence connectivity restraint between 1030-1037_bead  and  Residue_1038 of distance 4.32
# Adding sequence connectivity restraint between Residue_116  and  117-120_bead of distance 4.32
# Adding sequence connectivity restraint between 117-120_bead  and  Residue_121 of distance 4.32
# Adding sequence connectivity restraint between Residue_414  and  415-418_bead of distance 4.32
# Adding sequence connectivity restraint between 415-418_bead  and  Residue_419 of distance 4.32
# Adding sequence connectivity restraint between Residue_353  and  354-363_bead of distance 4.32
# Adding sequence connectivity restraint between 354-363_bead  and  364-373_bead of distance 4.32
# Adding sequence connectivity restraint between 364-373_bead  and  374-382_bead of distance 4.32
# Adding sequence connectivity restraint between 374-382_bead  and  Residue_383 of distance 4.32
# Adding sequence connectivity restraint between Residue_529  and  530-539_bead of distance 4.32
# Adding sequence connectivity restraint between 530-539_bead  and  540-549_bead of distance 4.32
# Adding sequence connectivity restraint between 540-549_bead  and  550-555_bead of distance 4.32
# Adding sequence connectivity restraint between 550-555_bead  and  Residue_556 of distance 4.32
# Adding sequence connectivity restraint between Residue_681  and  682-691_bead of distance 4.32
# Adding sequence connectivity restraint between 682-691_bead  and  692-699_bead of distance 4.32
# Adding sequence connectivity restraint between 692-699_bead  and  Residue_700 of distance 4.32
# Adding sequence connectivity restraint between Residue_771  and  772-781_bead of distance 4.32
# Adding sequence connectivity restraint between 772-781_bead  and  782-791_bead of distance 4.32
# Adding sequence connectivity restraint between 782-791_bead  and  792-801_bead of distance 4.32
# Adding sequence connectivity restraint between 792-801_bead  and  802-811_bead of distance 4.32
# Adding sequence connectivity restraint between 802-811_bead  and  812-821_bead of distance 4.32
# Adding sequence connectivity restraint between 812-821_bead  and  822_bead of distance 4.32
# Adding sequence connectivity restraint between 822_bead  and  Residue_823 of distance 4.32
# Adding sequence connectivity restraint between Residue_278  and  279-288_bead of distance 4.32
# Adding sequence connectivity restraint between 279-288_bead  and  289-298_bead of distance 4.32
# Adding sequence connectivity restraint between 289-298_bead  and  299-306_bead of distance 4.32
# Adding sequence connectivity restraint between 299-306_bead  and  Residue_307 of distance 4.32
# Adding sequence connectivity restraint between Residue_497  and  498-507_bead of distance 4.32
# Adding sequence connectivity restraint between 498-507_bead  and  508-517_bead of distance 4.32
# Adding sequence connectivity restraint between 508-517_bead  and  518-524_bead of distance 4.32
# Adding sequence connectivity restraint between 518-524_bead  and  Residue_525 of distance 4.32
# Adding sequence connectivity restraint between Residue_570  and  571-577_bead of distance 4.32
# Adding sequence connectivity restraint between 571-577_bead  and  Residue_578 of distance 4.32
# Adding sequence connectivity restraint between Residue_647  and  648-649_bead of distance 4.32
# Adding sequence connectivity restraint between 648-649_bead  and  Residue_650 of distance 4.32
# Adding sequence connectivity restraint between Residue_711  and  712-714_bead of distance 4.32
# Adding sequence connectivity restraint between 712-714_bead  and  Residue_715 of distance 4.32
# Adding sequence connectivity restraint between Residue_398  and  399-406_bead of distance 4.32
# Adding sequence connectivity restraint between 399-406_bead  and  Residue_407 of distance 4.32
# Adding sequence connectivity restraint between Residue_785  and  786-788_bead of distance 4.32
# Adding sequence connectivity restraint between 786-788_bead  and  Residue_789 of distance 4.32
# Adding sequence connectivity restraint between Residue_279  and  280-289_bead of distance 4.32
# Adding sequence connectivity restraint between 280-289_bead  and  290-293_bead of distance 4.32
# Adding sequence connectivity restraint between 290-293_bead  and  Residue_294 of distance 4.32
# Adding sequence connectivity restraint between Residue_478  and  479-488_bead of distance 4.32
# Adding sequence connectivity restraint between 479-488_bead  and  489-498_bead of distance 4.32
# Adding sequence connectivity restraint between 489-498_bead  and  499-508_bead of distance 4.32
# Adding sequence connectivity restraint between 499-508_bead  and  509-518_bead of distance 4.32
# Adding sequence connectivity restraint between 509-518_bead  and  519-528_bead of distance 4.32
# Adding sequence connectivity restraint between 519-528_bead  and  529-538_bead of distance 4.32
# Adding sequence connectivity restraint between 529-538_bead  and  539-548_bead of distance 4.32
# Adding sequence connectivity restraint between 539-548_bead  and  549-553_bead of distance 4.32
# Adding sequence connectivity restraint between 549-553_bead  and  Residue_554 of distance 4.32
# Adding sequence connectivity restraint between Residue_32  and  33-42_bead of distance 4.32
# Adding sequence connectivity restraint between 33-42_bead  and  43-52_bead of distance 4.32
# Adding sequence connectivity restraint between 43-52_bead  and  53-62_bead of distance 4.32
# Adding sequence connectivity restraint between 53-62_bead  and  63-64_bead of distance 4.32
# Adding sequence connectivity restraint between 63-64_bead  and  Residue_65 of distance 4.32
# Adding sequence connectivity restraint between Residue_331  and  332-341_bead of distance 4.32
# Adding sequence connectivity restraint between 332-341_bead  and  342_bead of distance 4.32
# Adding sequence connectivity restraint between 342_bead  and  Residue_343 of distance 4.32

# %% [markdown]
# ### Excluded Volume

# %%
# Excluded Volume Restraint
#  To speed up this expensive restraint, we evaluate it at resolution 10
ev = IMP.pmi.restraints.stereochemistry.ExcludedVolumeSphere(included_objects=cryo_molecules,
                                                             resolution=10)
ev.set_weight(ev_weight)
ev.add_to_model()
output_objects.append(ev)

# %%
# Quickly move all flexible beads into place
dof.optimize_flexible_beads(nsteps=100)
# Out:
# optimize_flexible_beads: optimizing 104 flexible beads

# %% [markdown]
# ## Sampling: Monte Carlo Replica Exchange

# %%
# --------------------------
# Monte-Carlo Sampling
# --------------------------

# This object defines all components to be sampled as well as the sampling protocol
mc1 = IMP.pmi.macros.ReplicaExchange0(m,
                                      root_hier=root_hierarchy,
                                      monte_carlo_sample_objects=dof.get_movers(),
                                      output_objects=output_objects,
                                      rmf_output_objects=output_objects,
                                      monte_carlo_temperature=mc_temperature,
                                      simulated_annealing=sim_annealing,
                                      simulated_annealing_minimum_temperature=min(sa_temps),
                                      simulated_annealing_maximum_temperature=max(sa_temps),
                                      simulated_annealing_minimum_temperature_nframes=sa_min_temp_steps,
                                      simulated_annealing_maximum_temperature_nframes=sa_max_temp_steps,
                                      replica_exchange_minimum_temperature=min(rex_temps),
                                      replica_exchange_maximum_temperature=max(rex_temps),
                                      number_of_best_scoring_models=num_best_scoring_models,
                                      monte_carlo_steps=num_mc_steps,
                                      number_of_frames=num_frames,
                                      global_output_directory=output_directory + "_" + str("SEC3"))

# Start Sampling
mc1.execute_macro()
# Out:
# Setting up MonteCarlo
# Setting up ReplicaExchange
# ReplicaExchange: Could not find MPI. Using Serial Replica Exchange
# Setting up stat file
# Stat info being written in the rmf file
# Setting up replica stat file
# Setting up best pdb files
# Setting up and writing initial rmf coordinate file
# got existing rex object
# Setting up production rmf files
# ReplicaExchange0: it generates initial.*.rmf3, stat.*.out, rmfs/*.rmf3 for each replica
# --- it stores the best scoring pdb models in pdbs/
# --- the stat.*.out and rmfs/*.rmf3 are saved only at the lowest temperature
# --- variables:
# ------ atomistic                      False
# ------ best_pdb_dir                   pdbs/
# ------ best_pdb_name_suffix           model
# ------ do_clean_first                 True
# ------ do_create_directories          True
# ------ geometries                     None
# ------ global_output_directory        ./output/cryoEM/output/iterations/wr_SEC3
# ------ initial_rmf_name_suffix        initial
# ------ molecular_dynamics_steps       10
# ------ monte_carlo_steps              50
# ------ monte_carlo_temperature        1.0
# ------ nframes_write_coordinates      1
# ------ num_sample_rounds              1
# ------ number_of_best_scoring_models  3
# ------ number_of_frames               100
# ------ number_of_states               2
# ------ replica_exchange_maximum_temperature 5.0
# ------ replica_exchange_minimum_temperature 1.0
# ------ replica_exchange_swap          True
# ------ replica_stat_file_suffix       stat_replica
# ------ rmf_dir                        rmfs/
# ------ save_coordinates_mode          lowest_temperature
# ------ self_adaptive                  False
# ------ simulated_annealing            True
# ------ simulated_annealing_maximum_temperature 5.0
# ------ simulated_annealing_maximum_temperature_nframes 20
# ------ simulated_annealing_minimum_temperature 1.0
# ------ simulated_annealing_minimum_temperature_nframes 100
# ------ stat_file_name_suffix          stat
# ------ write_initial_rmf              True
# --- frame 0 score 28367261.24800152
# --- writing coordinates
# --- frame 1 score 20468639.280382924
# --- writing coordinates
# --- frame 2 score 14235234.136297895
# --- writing coordinates
# --- frame 3 score 9377672.1998204
# --- writing coordinates
# --- frame 4 score 6115107.482911184
# --- writing coordinates
# --- frame 5 score 3839912.804953929
# --- writing coordinates
# --- frame 6 score 2354687.2890100046
# --- writing coordinates
# --- frame 7 score 1482099.1464321006
# --- writing coordinates
# --- frame 8 score 911475.6952349712
# --- writing coordinates
# --- frame 9 score 546059.7693961465
# --- writing coordinates
# --- frame 10 score 330623.739623906
# --- writing coordinates
# --- frame 11 score 171217.60025980131
# --- writing coordinates
# --- frame 12 score 87132.69813303203
# --- writing coordinates
# --- frame 13 score 46794.898936966776
# --- writing coordinates
# --- frame 14 score 29456.481317950536
# --- writing coordinates
# --- frame 15 score 18270.653598668465
# --- writing coordinates
# --- frame 16 score 12431.486328077066
# --- writing coordinates
# --- frame 17 score 10104.37790414011
# --- writing coordinates
# --- frame 18 score 8035.612506387335
# --- writing coordinates
# --- frame 19 score 6897.136151202134
# --- writing coordinates
# --- frame 20 score 6107.101751504683
# --- writing coordinates
# --- frame 21 score 5737.056971877647
# --- writing coordinates
# --- frame 22 score 5512.938096648919
# --- writing coordinates
# --- frame 23 score 5274.431481907812
# --- writing coordinates
# --- frame 24 score 5111.71213987095
# --- writing coordinates
# --- frame 25 score 4894.981321853881
# --- writing coordinates
# --- frame 26 score 4732.417220852859
# --- writing coordinates
# --- frame 27 score 4577.6116019059955
# --- writing coordinates
# --- frame 28 score 4495.93498204309
# --- writing coordinates
# --- frame 29 score 4337.236861254239
# --- writing coordinates
# --- frame 30 score 4232.080678770179
# --- writing coordinates
# --- frame 31 score 4116.841348231468
# --- writing coordinates
# --- frame 32 score 4037.9208429518544
# --- writing coordinates
# --- frame 33 score 3870.2797606005443
# --- writing coordinates
# --- frame 34 score 3844.3475760821707
# --- writing coordinates
# --- frame 35 score 3738.399660468137
# --- writing coordinates
# --- frame 36 score 3692.6585871194147
# --- writing coordinates
# --- frame 37 score 3661.0447116747987
# --- writing coordinates
# --- frame 38 score 3561.6043946094687
# --- writing coordinates
# --- frame 39 score 3531.9320581185298
# --- writing coordinates
# --- frame 40 score 3461.918823313967
# --- writing coordinates
# --- frame 41 score 3431.794205346225
# --- writing coordinates
# --- frame 42 score 3400.1044946648976
# --- writing coordinates
# --- frame 43 score 3372.737795447692
# --- writing coordinates
# --- frame 44 score 3361.7029241809983
# --- writing coordinates
# --- frame 45 score 3317.7743035073236
# --- writing coordinates
# --- frame 46 score 3270.485514659146
# --- writing coordinates
# --- frame 47 score 3206.8449962781297
# --- writing coordinates
# --- frame 48 score 3173.8934766758603
# --- writing coordinates
# --- frame 49 score 3131.264374399005
# --- writing coordinates
# --- frame 50 score 3104.7021740333444
# --- writing coordinates
# --- frame 51 score 3084.680002160879
# --- writing coordinates
# --- frame 52 score 3069.579836290482
# --- writing coordinates
# --- frame 53 score 3043.325308401353
# --- writing coordinates
# --- frame 54 score 3004.213395524967
# --- writing coordinates
# --- frame 55 score 2980.525987895203
# --- writing coordinates
# --- frame 56 score 2968.2972667820195
# --- writing coordinates
# --- frame 57 score 2932.207178817847
# --- writing coordinates
# --- frame 58 score 2897.832711385603
# --- writing coordinates
# --- frame 59 score 2894.175390964765
# --- writing coordinates
# --- frame 60 score 2879.087840704342
# --- writing coordinates
# --- frame 61 score 2872.892316546722
# --- writing coordinates
# --- frame 62 score 2844.7941913827485
# --- writing coordinates
# --- frame 63 score 2836.233910918847
# --- writing coordinates
# --- frame 64 score 2821.1419720165404
# --- writing coordinates
# --- frame 65 score 2801.776813394898
# --- writing coordinates
# --- frame 66 score 2776.5735953765798
# --- writing coordinates
# --- frame 67 score 2778.847418955382
# --- writing coordinates
# --- frame 68 score 2756.602492937186
# --- writing coordinates
# --- frame 69 score 2733.9452690356775
# --- writing coordinates
# --- frame 70 score 2698.5741621883985
# --- writing coordinates
# --- frame 71 score 2681.4241867399705
# --- writing coordinates
# --- frame 72 score 2678.046133883119
# --- writing coordinates
# --- frame 73 score 2667.3303139734853
# --- writing coordinates
# --- frame 74 score 2629.911919798406
# --- writing coordinates
# --- frame 75 score 2627.9044307569147
# --- writing coordinates
# --- frame 76 score 2611.9387419955337
# --- writing coordinates
# --- frame 77 score 2586.6528846159454
# --- writing coordinates
# --- frame 78 score 2563.8904170841643
# --- writing coordinates
# --- frame 79 score 2566.9086878998714
# --- writing coordinates
# --- frame 80 score 2562.7591477818196
# --- writing coordinates
# --- frame 81 score 2559.7812577961167
# --- writing coordinates
# --- frame 82 score 2536.9046440904895
# --- writing coordinates
# --- frame 83 score 2522.8512450108924
# --- writing coordinates
# --- frame 84 score 2506.3533381339676
# --- writing coordinates
# --- frame 85 score 2507.68866315143
# --- writing coordinates
# --- frame 86 score 2493.7251936834355
# --- writing coordinates
# --- frame 87 score 2486.7961097275747
# --- writing coordinates
# --- frame 88 score 2493.8287045444813
# --- writing coordinates
# --- frame 89 score 2467.0482605879797
# --- writing coordinates
# --- frame 90 score 2449.174972596027
# --- writing coordinates
# --- frame 91 score 2453.224315931992
# --- writing coordinates
# --- frame 92 score 2443.827056336107
# --- writing coordinates
# --- frame 93 score 2428.062843582497
# --- writing coordinates
# --- frame 94 score 2427.672876891992
# --- writing coordinates
# --- frame 95 score 2423.833609719051
# --- writing coordinates
# --- frame 96 score 2440.2773084904034
# --- writing coordinates
# --- frame 97 score 2420.5318834088976
# --- writing coordinates
# --- frame 98 score 2419.439581998208
# --- writing coordinates
# --- frame 99 score 2436.033126020702
# --- writing coordinates
# closing production rmf files

# %% [markdown]
# ## Output

# %% [markdown]
# IMP returns an output directory with:
# - stats files --> files for analysis
# - rmf --> file to see the iterations (open with Chimera)
# - pdbs --> pdbs for each "state"
# - initial.0.rmf3 --> Initial frame before the iterations.
